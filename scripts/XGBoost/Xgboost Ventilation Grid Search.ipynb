# %%
##This notebook uses xgboost with grid search
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataset = spark.table("mldata_ventilation_status")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
label = "ventilation_status"
allColumns = dataset.columns

categoricalColumns = [
  "City",
  "Marital",
  "Race",
  "Ethnicity",
  "Gender",
  "Suffix",
  "County",
#   "State",
  "smoker_status"
]

# numericalColumns = ["num1",
#                     "num2"]

ignoreColumns = ["Patient", "dataset", "State", label]

numericalColumns = list(set(allColumns) - set(categoricalColumns) - set(ignoreColumns))
# print(numericalColumns)

#categoricalColumnsclassVec = [c + "classVec" for c in categoricalColumns]

stages = []
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, OneHotEncoderEstimator, StringIndexer, VectorAssembler
from pyspark.sql.functions import *

for categoricalColumn in categoricalColumns:
  print(categoricalColumn)
  ## Category Indexing with StringIndexer
  stringIndexer = StringIndexer(inputCol=categoricalColumn, outputCol = categoricalColumn+"Index").setHandleInvalid("skip")
  ## Use OneHotEncoder to convert categorical variables into binary SparseVectors
  #encoder = OneHotEncoder(inputCol=categoricalColumn+"Index", outputCol=categoricalColumn+"classVec")
  ## Add stages
  stages += [stringIndexer]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">City
# Marital
# Race
# Ethnicity
# Gender
# Suffix
# County
# smoker_status
# </div>

# %%
prepPipeline = Pipeline().setStages(stages)
# pipelineModel = prepPipeline.fit(train)
pipelineModel = prepPipeline.fit(dataset)
dataset = pipelineModel.transform(dataset)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train = dataset.filter(col("dataset") == "train")
train = train.filter(col("ventilation_status").isNotNull())
training, validation = train.randomSplit([0.8, 0.2], seed = 123)


test = dataset.filter(col("dataset") == "test")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(training.count())
print(training.select("Patient").distinct().count())
print(validation.count())
print(validation.select("Patient").distinct().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">58898
# 58898
# 14799
# 14799
# </div>

# %%
target = 'ventilation_status'
ignoreColumns = ["Patient", "dataset", "State", 'label']
ignoreColumns2 = ["Patient", "dataset", "State", 'label',target]
columnCast=list(set(dataset.columns) - set(categoricalColumns) - set(ignoreColumns))
predictors=list(set(dataset.columns) - set(categoricalColumns) - set(ignoreColumns2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd

trainCast=training.select(*(col(c).cast("float").alias(c) for c in columnCast)).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/types.py:1642: DeprecationWarning: Using or importing the ABCs from &#39;collections&#39; instead of from &#39;collections.abc&#39; is deprecated, and in 3.8 it will stop working
#   return pa.schema(fields)
# </div>

# %%
validationCast=validation.select(*(col(c).cast("float").alias(c) for c in columnCast)).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import xgboost as xgb
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
xgb_params = {
    'learning_rate':    [.03, 0.05, .07],
    'max_depth':        [5, 6,7],
    'min_child_weight': [4,3,2],
    'colsample_bytree': [.3,.5,.7],
    'subsample':       [0.8, 1],
    'n_estimators':     [100],
    'eval_metric': ['auc'],
    'early_stopping_rounds': [10],
    'objective':['binary:logistic']
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
xgb1=xgb.XGBClassifier()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.model_selection import GridSearchCV

xgb_grid = GridSearchCV(xgb1,
                        xgb_params,
                        cv = 2,
                        n_jobs = 5,
                        verbose=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train2=trainCast[predictors]
valid=validationCast[predictors]

#y_train = train.target
#y_valid = valid.target
y_train=trainCast.ventilation_status
y_valid=validationCast.ventilation_status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
xgb_grid.fit(train2,
         y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: GridSearchCV(cv=2, error_score=&#39;raise-deprecating&#39;,
#        estimator=XGBClassifier(base_score=0.5, booster=&#39;gbtree&#39;, colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective=&#39;binary:logistic&#39;, random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1),
#        fit_params=None, iid=&#39;warn&#39;, n_jobs=5,
#        param_grid={&#39;learning_rate&#39;: [0.03, 0.05, 0.07], &#39;max_depth&#39;: [5, 6, 7], &#39;min_child_weight&#39;: [4, 3, 2], &#39;colsample_bytree&#39;: [0.3, 0.5, 0.7], &#39;subsample&#39;: [0.8, 1], &#39;n_estimators&#39;: [100], &#39;eval_metric&#39;: [&#39;auc&#39;], &#39;early_stopping_rounds&#39;: [10], &#39;objective&#39;: [&#39;binary:logistic&#39;]},
#        pre_dispatch=&#39;2*n_jobs&#39;, refit=True, return_train_score=&#39;warn&#39;,
#        scoring=None, verbose=False)</div>

# %%
print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.9446670515127848
# {&#39;colsample_bytree&#39;: 0.5, &#39;early_stopping_rounds&#39;: 10, &#39;eval_metric&#39;: &#39;auc&#39;, &#39;learning_rate&#39;: 0.07, &#39;max_depth&#39;: 5, &#39;min_child_weight&#39;: 4, &#39;n_estimators&#39;: 100, &#39;objective&#39;: &#39;binary:logistic&#39;, &#39;subsample&#39;: 1}
# </div>

# %%
from sklearn.metrics import roc_auc_score

pred_valid=xgb_grid.predict_proba(valid)[:,1]
auc_valid=roc_auc_score(y_valid, pred_valid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred_train=xgb_grid.predict_proba(train2)[:,1]
auc_train=roc_auc_score(y_train, pred_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.metrics import average_precision_score

pr_valid=average_precision_score(y_valid, pred_valid)
pr_train=average_precision_score(y_train, pred_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(auc_train)
print(auc_valid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.8477805329653313
# 0.8047527870457654
# </div>

# %%
print(pr_train)
print(pr_valid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.380136809293668
# 0.24678580630301214
# </div>

# %%
import pickle

with open('/dbfs/mnt/data/ml/ventilationstatus/xg/model.pkl', 'wb') as f:
    pickle.dump(xgb_grid, f)

display(dbutils.fs.ls("/mnt/data/ml/ventilationstatus/xg/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/ml/ventilationstatus/xg/model.pkl</td><td>model.pkl</td><td>250683</td></tr><tr><td>dbfs:/mnt/data/ml/ventilationstatus/xg/placeholder.txt</td><td>placeholder.txt</td><td>0</td></tr></tbody></table></div>

# %%
xgb_grid.best_estimator_.get_params()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: {&#39;base_score&#39;: 0.5,
#  &#39;booster&#39;: &#39;gbtree&#39;,
#  &#39;colsample_bylevel&#39;: 1,
#  &#39;colsample_bynode&#39;: 1,
#  &#39;colsample_bytree&#39;: 0.5,
#  &#39;gamma&#39;: 0,
#  &#39;learning_rate&#39;: 0.07,
#  &#39;max_delta_step&#39;: 0,
#  &#39;max_depth&#39;: 5,
#  &#39;min_child_weight&#39;: 4,
#  &#39;missing&#39;: None,
#  &#39;n_estimators&#39;: 100,
#  &#39;n_jobs&#39;: 1,
#  &#39;nthread&#39;: None,
#  &#39;objective&#39;: &#39;binary:logistic&#39;,
#  &#39;random_state&#39;: 0,
#  &#39;reg_alpha&#39;: 0,
#  &#39;reg_lambda&#39;: 1,
#  &#39;scale_pos_weight&#39;: 1,
#  &#39;seed&#39;: None,
#  &#39;silent&#39;: None,
#  &#39;subsample&#39;: 1,
#  &#39;verbosity&#39;: 1,
#  &#39;early_stopping_rounds&#39;: 10,
#  &#39;eval_metric&#39;: &#39;auc&#39;}</div>

# %%
feature_importances = pd.DataFrame({'Feature': valid.columns,
                                   'Importance': xgb_grid.best_estimator_.feature_importances_}).sort_values(by=['Importance'], ascending = False)

feature_importances
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Feature</th>
#       <th>Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>352</th>
#       <td>6298-4_Min</td>
#       <td>0.025339</td>
#     </tr>
#     <tr>
#       <th>804</th>
#       <td>age_years</td>
#       <td>0.022874</td>
#     </tr>
#     <tr>
#       <th>189</th>
#       <td>Revenue</td>
#       <td>0.018139</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>QALY_Min</td>
#       <td>0.017974</td>
#     </tr>
#     <tr>
#       <th>277</th>
#       <td>condition_126906006</td>
#       <td>0.016433</td>
#     </tr>
#     <tr>
#       <th>516</th>
#       <td>QALY_Max</td>
#       <td>0.013441</td>
#     </tr>
#     <tr>
#       <th>158</th>
#       <td>procedure_265764009</td>
#       <td>0.012892</td>
#     </tr>
#     <tr>
#       <th>483</th>
#       <td>condition_424132000</td>
#       <td>0.011206</td>
#     </tr>
#     <tr>
#       <th>681</th>
#       <td>condition_64859006</td>
#       <td>0.010236</td>
#     </tr>
#     <tr>
#       <th>430</th>
#       <td>condition_92691004</td>
#       <td>0.010151</td>
#     </tr>
#     <tr>
#       <th>669</th>
#       <td>Healthcare_Coverage</td>
#       <td>0.009715</td>
#     </tr>
#     <tr>
#       <th>425</th>
#       <td>20565-8_Max</td>
#       <td>0.009351</td>
#     </tr>
#     <tr>
#       <th>537</th>
#       <td>careplan_736252007</td>
#       <td>0.009078</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>medication_1659149</td>
#       <td>0.008923</td>
#     </tr>
#     <tr>
#       <th>637</th>
#       <td>medication_205923</td>
#       <td>0.008879</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>49765-1_StdDev</td>
#       <td>0.008011</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>procedure_703423002</td>
#       <td>0.007813</td>
#     </tr>
#     <tr>
#       <th>367</th>
#       <td>condition_713197008</td>
#       <td>0.007702</td>
#     </tr>
#     <tr>
#       <th>797</th>
#       <td>medication_583214</td>
#       <td>0.007667</td>
#     </tr>
#     <tr>
#       <th>320</th>
#       <td>condition_53741008</td>
#       <td>0.007616</td>
#     </tr>
#     <tr>
#       <th>316</th>
#       <td>718-7_Min</td>
#       <td>0.007435</td>
#     </tr>
#     <tr>
#       <th>346</th>
#       <td>49765-1_Max</td>
#       <td>0.007163</td>
#     </tr>
#     <tr>
#       <th>563</th>
#       <td>QALY_Avg</td>
#       <td>0.007099</td>
#     </tr>
#     <tr>
#       <th>211</th>
#       <td>medication_705129</td>
#       <td>0.006746</td>
#     </tr>
#     <tr>
#       <th>264</th>
#       <td>DALY_Avg</td>
#       <td>0.006588</td>
#     </tr>
#     <tr>
#       <th>462</th>
#       <td>medication_309362</td>
#       <td>0.006586</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>medication_1736854</td>
#       <td>0.006569</td>
#     </tr>
#     <tr>
#       <th>545</th>
#       <td>condition_67811000119102</td>
#       <td>0.006472</td>
#     </tr>
#     <tr>
#       <th>310</th>
#       <td>medication_1734340</td>
#       <td>0.006405</td>
#     </tr>
#     <tr>
#       <th>416</th>
#       <td>38483-4_Max</td>
#       <td>0.006266</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>357</th>
#       <td>procedure_88039007</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>359</th>
#       <td>procedure_104375008</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>360</th>
#       <td>medication_197541</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>361</th>
#       <td>procedure_385798007</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>362</th>
#       <td>1751-7_StdDev</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>363</th>
#       <td>1920-8_StdDev</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>364</th>
#       <td>procedure_52734007</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>366</th>
#       <td>procedure_445912000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>368</th>
#       <td>condition_79586000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>340</th>
#       <td>condition_44054006</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>338</th>
#       <td>condition_70704007</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>336</th>
#       <td>procedure_305428000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>324</th>
#       <td>condition_287185009</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>311</th>
#       <td>condition_38822007</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>312</th>
#       <td>medication_1856546</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>313</th>
#       <td>condition_86849004</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>315</th>
#       <td>condition_80394007</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>317</th>
#       <td>procedure_609588000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>321</th>
#       <td>condition_94260004</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>322</th>
#       <td>condition_84757009</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>325</th>
#       <td>medication_198240</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>procedure_167271000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>789-8_Avg</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>327</th>
#       <td>787-2_StdDev</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>328</th>
#       <td>City_Age_15_19</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>329</th>
#       <td>medication_857005</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>330</th>
#       <td>condition_24079001</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>331</th>
#       <td>17861-6_Min</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>333</th>
#       <td>785-6_StdDev</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>823</th>
#       <td>condition_33737001</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p>824 rows × 2 columns</p>
# </div>

# %%
from pyspark.ml import Pipeline, PipelineModel
from pyspark.ml.tuning import CrossValidatorModel
from pyspark.sql.functions import *
from pyspark.sql.types import IntegerType, FloatType
## Function to extract probability from array
getprob = udf(lambda v:float(v[1]),FloatType())

## Load in COVID-19 Predictions
cv19test = spark.table("mldata_covid19_status").filter(col("dataset") == "test")

pipelineModel = PipelineModel.load("/mnt/data/ml/covid19status/pipeline")
cv19test = pipelineModel.transform(cv19test)

cvModel = CrossValidatorModel.load("/mnt/data/ml/covid19status/rf")
cv19test = cvModel.bestModel.transform(cv19test)

cv19test = cv19test.select(col("Patient"),         
                           getprob(col("probability")).alias("probability"),
                           col("prediction"))

###########################################################

testCast = test.select(*(col(c).cast("float").alias(c) for c in columnCast)).toPandas()

pred_test = xgb_grid.predict_proba(testCast[predictors])[:,1]

test_output = test.select("Patient").toPandas()
test_output["probability"] = pred_test

test_output = spark.createDataFrame(test_output) \
                   .join(cv19test.drop("probability").withColumnRenamed("prediction", "cv_prediction"), on=["Patient"], how="left") \
                   .withColumn("probability", when(col("cv_prediction") == 0, lit(0)).otherwise(col("probability"))) \
                   .drop("cv_prediction")

test_output.coalesce(1) \
      .write.format("com.databricks.spark.csv") \
      .option("header", "false") \
      .save("/mnt/data/scored/ventilationstatus/xgboost/")

display(test_output)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Patient</th><th>probability</th></tr></thead><tbody><tr><td>046495b9-e1cd-47df-bc24-995e9807248f</td><td>0.009627958</td></tr><tr><td>076ba84e-6fd5-4024-92cc-28c3f10e42cc</td><td>0.0</td></tr><tr><td>08170598-af43-40c5-b1f6-f9e2a61261b0</td><td>0.0</td></tr><tr><td>08b13997-1dd1-4447-9da7-8e831ec12116</td><td>0.00778181</td></tr><tr><td>09f29ef9-559d-4d7e-abb2-b112fe29a441</td><td>0.0324391</td></tr><tr><td>0a18e6ae-4b9d-4ef9-9906-cdb803c7ca44</td><td>0.0</td></tr><tr><td>0deb965a-447e-4d2e-a751-ef1bda118122</td><td>0.0</td></tr><tr><td>1010bd6b-5789-4165-9a1e-e9be0db8373e</td><td>0.106460154</td></tr><tr><td>123bf5e8-493e-487e-9e99-03f5858ddeca</td><td>0.0</td></tr><tr><td>125885b6-2f5e-4ee3-ac59-d6b88afb1e59</td><td>0.0</td></tr><tr><td>125c94e8-2347-4dd6-bb20-d7a49554d87d</td><td>0.074083984</td></tr><tr><td>14055d76-54f9-4ea6-bccb-43c1b02fa127</td><td>0.033196777</td></tr><tr><td>14b55308-9c1c-4387-b79c-fed1491119b0</td><td>0.0</td></tr><tr><td>156607f9-7961-47f9-878a-605e7ef4b6a2</td><td>0.0</td></tr><tr><td>171cf12c-8365-4e0e-a129-48b65e40ea4d</td><td>0.017016778</td></tr><tr><td>1872c5d0-ca35-4363-abdd-04bbfe51541c</td><td>0.0</td></tr><tr><td>1ca94612-789e-414c-aacb-9234eefddf31</td><td>0.0</td></tr><tr><td>1e626f5f-bed6-4670-9d69-29f7788b7afd</td><td>0.007911943</td></tr><tr><td>255f8f0f-071a-4482-88be-4d8aa97fdbd1</td><td>0.03187851</td></tr><tr><td>25e4edc5-777d-4a35-b172-d100f39960a8</td><td>0.011135252</td></tr><tr><td>2708325f-b0dc-4362-97d9-1ce6eac4b83a</td><td>0.043414775</td></tr><tr><td>2db26758-f529-442b-8428-0a6675b21a26</td><td>0.011836683</td></tr><tr><td>2e8b0aa1-51ab-4bed-8185-d3d9a92fdf35</td><td>0.2845743</td></tr><tr><td>30ea121b-5603-45f3-bf24-a1fb65ca4dd7</td><td>0.0</td></tr><tr><td>32a23a2b-426a-412a-98b9-dd471c198605</td><td>0.03873727</td></tr><tr><td>32dc0cec-60de-4fe6-9196-e5d326f8565a</td><td>0.010016871</td></tr><tr><td>33a2e06f-2bf9-4641-9672-93055e986a2c</td><td>0.024810536</td></tr><tr><td>361fd2ad-0d71-4cea-9a0e-db837a3394c8</td><td>0.099399485</td></tr><tr><td>370e2913-abf9-4c3e-889d-1b214692d476</td><td>0.00853902</td></tr><tr><td>39d63b18-4fea-49f6-8a73-32ceb9f55a04</td><td>0.011873338</td></tr><tr><td>39fc4adc-39a4-41d0-a2bf-74b8895a534a</td><td>0.11911254</td></tr><tr><td>3b7dc472-777c-4b20-8b65-f36d91f55329</td><td>0.007487488</td></tr><tr><td>3be2d306-35b5-4afa-b5d6-3b74bce296d9</td><td>0.06678825</td></tr><tr><td>3c300a33-68b3-4472-b866-c9312f1c16b8</td><td>0.1514609</td></tr><tr><td>3dfc4e76-ad8c-4340-acb1-045bfba55f8b</td><td>0.0</td></tr><tr><td>3fbae55d-c18e-4c84-88fd-56357953cfea</td><td>0.009998484</td></tr><tr><td>40235549-d6f8-4c1c-8f87-12725ed7ceca</td><td>0.0820131</td></tr><tr><td>454ff0c4-7205-40b4-9a0c-abeb8149ae07</td><td>0.102044895</td></tr><tr><td>4591337b-f93e-4898-871b-dfa3c7aef521</td><td>0.28976965</td></tr><tr><td>460bb6ae-b8ed-43c2-8791-44a3ae72adbd</td><td>0.029903939</td></tr><tr><td>474f951e-9478-4ae4-a655-183fe7c3a1b9</td><td>0.13731551</td></tr><tr><td>47a42159-30df-4d69-a10c-0b66d547925d</td><td>0.0</td></tr><tr><td>4a845038-b515-4a46-9719-6220cff41633</td><td>0.04422439</td></tr><tr><td>4b5db7bd-d389-46bf-b725-e647d781dc96</td><td>0.0</td></tr><tr><td>4c1cceb0-236b-4c32-8022-2c9d81d98d04</td><td>0.019654265</td></tr><tr><td>4d3722be-be30-409d-a5cf-3874d14a743b</td><td>0.010110095</td></tr><tr><td>4ea4aaa4-0c1a-473b-93cc-05cc6a21d617</td><td>0.0131092975</td></tr><tr><td>4f3ec3e6-bec8-4eb5-87ae-7f4d1294140b</td><td>0.0</td></tr><tr><td>50d4dddd-a393-44b6-b6ad-c16f2c651a24</td><td>0.053752054</td></tr><tr><td>515a5cc7-f543-4938-9966-fae04fcd7fa9</td><td>0.15320364</td></tr><tr><td>53116970-4e00-4cbc-a49c-85a51ab87c1c</td><td>0.0</td></tr><tr><td>54dbc986-23b3-4644-88b1-10c2d0b420a5</td><td>0.023885822</td></tr><tr><td>55bdb64e-10e1-47dd-a7e2-461f2499215a</td><td>0.086861275</td></tr><tr><td>58dd518f-11ae-40c6-bdd2-dd4603f7eaf9</td><td ...
